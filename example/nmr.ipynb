# %%
from nmr import NMRSpectrum

# %%
spectrum = NMRSpectrum('1H')

# %%
spectrum.fft()

# %%
spectrum.gen_x_scale()

# %%
spectrum.phase(30, 0)

# %%
spectrum.reference(1.96)

# %%
spectrum.normalize()

# %%
spectrum.cut(2.5, 12)

# %%
spectrum.show()
